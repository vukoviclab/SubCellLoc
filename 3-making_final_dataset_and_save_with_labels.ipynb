# %%
import pandas as pd
import glob
from rdkit.DataStructs.cDataStructs import ConvertToNumpyArray
import os
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
csv_list = glob.glob('*_sub_location.csv')
csv_list
# Out:
# ['chembl_sub_location.csv',
#  'drug_central_sub_location.csv',
#  'pharos_sub_location.csv']

# %%
df = pd.concat([pd.read_csv(csv_file) for csv_file in csv_list])
df.dropna(subset=['location'],inplace=True)
df
# Out:
#     uni_prot_id                                           location
# 0        P04053                                            Nucleus
# 1        P02766                                Secreted, Cytoplasm
# 2        P61026  Cytoplasmic vesicle membrane Lipid-anchor Cyto...
# 3        P40429                                          Cytoplasm
# 4        P49685          Cell membrane Multi-pass membrane protein
# ..          ...                                                ...
# 952      Q9Y5Y4          Cell membrane Multi-pass membrane protein
# 953      P26439  Endoplasmic reticulum membrane Single-pass mem...
# 954      P36888  Membrane Single-pass type I membrane protein, ...
# 955      Q5JUK3          Cell membrane Multi-pass membrane protein
# 956      P01584  Cytoplasm Cytosol, Secreted, Lysosome, Secrete...
#
# [4029 rows x 2 columns]

# %%
df[df['location'].str.contains('synapse')].loc[101]['location']
# Out:
# 'Cell membrane Peripheral membrane protein, Membrane Clathrin-coated pit, Presynapse'

# %%
df[~df['location'].str.contains('synapse')]
# Out:
#     uni_prot_id                                           location
# 0        P04053                                            Nucleus
# 1        P02766                                Secreted, Cytoplasm
# 2        P61026  Cytoplasmic vesicle membrane Lipid-anchor Cyto...
# 3        P40429                                          Cytoplasm
# 4        P49685          Cell membrane Multi-pass membrane protein
# ..          ...                                                ...
# 952      Q9Y5Y4          Cell membrane Multi-pass membrane protein
# 953      P26439  Endoplasmic reticulum membrane Single-pass mem...
# 954      P36888  Membrane Single-pass type I membrane protein, ...
# 955      Q5JUK3          Cell membrane Multi-pass membrane protein
# 956      P01584  Cytoplasm Cytosol, Secreted, Lysosome, Secrete...
#
# [4008 rows x 2 columns]

# %%
df_synapse = df[df['location'].str.contains('synapse')]

# %%
def all_synapse(s):
    words = s.split(',')
    return all('synapse' in word.lower() for word in words)

df_synapse.loc[df_synapse['location'].apply(all_synapse), 'location'] = np.nan
df_synapse
# Out:
# /tmp/ipykernel_454038/2594861034.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_synapse.loc[df_synapse['location'].apply(all_synapse), 'location'] = np.nan
#      uni_prot_id                                           location
# 94        O15056  Cytoplasm, Cell membrane, Membrane raft, Presy...
# 471       Q09470  Cell membrane Multi-pass membrane protein, Mem...
# 496       P42261  Cell membrane Multi-pass membrane protein, End...
# 1353      P35626                                                NaN
# 1380      Q9C0H9  Cytoplasm, Cytoplasm Cytoskeleton, Cell projec...
# 1392      Q2M2I8  Cell membrane Peripheral membrane protein, Mem...
# 1694      P28223  Cell membrane Multi-pass membrane protein, Cel...
# 1958      P78352  Cell membrane Lipid-anchor Cytoplasmic side, P...
# 2556      P21554  Cell membrane Multi-pass membrane protein, Mem...
# 2726      P30531  Cell membrane Multi-pass membrane protein, Pre...
# 2847      Q9Y6A2  Endoplasmic reticulum membrane Single-pass mem...
# 3086      P25098  Cytoplasm, Cell membrane, Postsynapse, Presynapse
# 101       Q2M2I8  Cell membrane Peripheral membrane protein, Mem...
# 32        P21554  Cell membrane Multi-pass membrane protein, Mem...
# 33        Q7L0J3  Presynapse, Cytoplasmic vesicle Secretory vesi...
# 110       P30531  Cell membrane Multi-pass membrane protein, Pre...
# 405       Q2M2I8  Cell membrane Peripheral membrane protein, Mem...
# 612       Q09470  Cell membrane Multi-pass membrane protein, Mem...
# 666       Q5XXA6  Apical cell membrane Multi-pass membrane prote...
# 762       P42261  Cell membrane Multi-pass membrane protein, End...
# 918       P28223  Cell membrane Multi-pass membrane protein, Cel...

# %%
df_pharos = pd.read_csv('pharos.csv')
df_pharos = df_pharos[['smiles','uniprot']]
df_pharos
# Out:
#                                                  smiles uniprot
# 0     CCCCC1(CCCC)CN(C2=CC=CC=C2)C2=C(C=C(OCC(=O)N[C...  Q12908
# 1     CC(C)(CO)C1=CC2=C(C=C(F)C(NC(=O)C3(CC3)C3=CC=C...  P13569
# 2                                                   NaN  P13569
# 3     CC(C)(C)C1=CC(=C(NC(=O)C2=CNC3=CC=CC=C3C2=O)C=...  P13569
# 4     CC1=CC=C(NC(=O)C2(CC2)C2=CC=C3OC(F)(F)OC3=C2)N...  P13569
# ...                                                 ...     ...
# 3862  [H][C@]12C[C@]([H])([C@@H](OC)[C@](C)(O1)N1C3=...  Q16513
# 3863  [H][C@]12C[C@]([H])([C@@H](OC)[C@](C)(O1)N1C3=...  Q9UHD2
# 3864  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  O00506
# 3865  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9P289
# 3866  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9Y6E0
#
# [3867 rows x 2 columns]

# %%
df_chembl = pd.read_csv('chembl.csv')
df_chembl = df_chembl[['SMILES','UniProt_ID']]
df_chembl = df_chembl.rename(columns={'SMILES': 'smiles', 'UniProt_ID': 'uniprot'})
df_chembl
# Out:
#                                                    smiles uniprot
# 0                              CC(=N)NCCSCC[C@H](N)C(=O)O  P35228
# 1                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P20309
# 2                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P08172
# 3                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  Q92731
# 4                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  P03372
# ...                                                   ...     ...
# 394540  CCn1c(C(=O)N(C2CC2)C2CC2)cc2c3c(ncn3C)c(Nc3cc(...  Q05397
# 394541  CCn1c(C(=O)N(C2CC2)C2CC2)cc2c3c(ncn3C)c(Nc3cc(...  P07949
# 394542  CCn1c(C(=O)N(C2CC2)C2CC2)cc2c3c(ncn3C)c(Nc3cc(...  P12931
# 394543  CCn1c(C(=O)N(C2CC2)C2CC2)cc2c3c(ncn3C)c(Nc3cc(...  Q9Y6E0
# 394544  CCn1c(C(=O)N(C2CC2)C2CC2)cc2c3c(ncn3C)c(Nc3cc(...  P36897
#
# [394545 rows x 2 columns]

# %%
df_drug_central = pd.read_csv('drug_central/tchem_drugs_05122020.tsv',sep='\t')
df_drug_central = df_drug_central[['smiles','uniprot']]
df_drug_central
# Out:
#                                                 smiles uniprot
# 0    COC1=C(OCCCN2CCOCC2)C=CC2=C1N=C(NC(=O)C1=CN=C(...  P42338
# 1    O=C1NC2=C(C=C1)C=CC(OCCCCN1CCN(CC1)C1=C3C=CSC3...  P21917
# 2    O=C1NC2=C(C=C1)C=CC(OCCCCN1CCN(CC1)C1=C3C=CSC3...  P50406
# 3    NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...  P51575
# 4    NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...  Q99571
# ..                                                 ...     ...
# 638  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9Y6E0
# 639  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q8IVH8
# 640  COC1=CC(NC2=NC(NC3=CC=C4OC(C)(C)C(=O)N(COP(O)(...  P0DMS8
# 641  CCN(C1CCOCC1)C1=CC(=CC(C(=O)NCC2=C(C)C=C(C)NC2...  Q92800
# 642              FC1=C(C=CC(=C1)C#N)[C@H]1CCC2=CN=CN12  P19099
#
# [643 rows x 2 columns]

# %%
df_all = pd.concat([df_chembl, df_pharos, df_drug_central])
df_all = (
    df_all.dropna(subset=['smiles'])
    .drop_duplicates()
    .merge(df, left_on='uniprot', right_on='uni_prot_id', how='left')
    .drop_duplicates()
)
mask = (df_all['uni_prot_id'] != 'P35626') & (df_all['location'].notna()) & (~df_all['location'].str.contains('synapse', case=False, na=False))
df_all = df_all[mask]
df_all['location'] = df_all['location'].str.replace(', ', ',').str.lower().str.split(',')

# %%
df_all = pd.concat([df_chembl,df_pharos,df_drug_central])
df_all.dropna(subset=['smiles'],inplace=True)
df_all.drop_duplicates(inplace=True)
df_all = df_all.merge(df, left_on='uniprot', right_on='uni_prot_id', how='left')
df_all.drop_duplicates(inplace = True)
df_all = df_all[df_all['uni_prot_id']!='P35626']
df_all.dropna(subset=['location'],inplace=True)
df_all = df_all[df_all['location']!= np.nan]
df_all = df_all[~df_all['location'].str.contains('synapse', case=False)]
df_all['location'] = df_all['location'].str.replace(', ', ',').str.lower()
df_all['location'] = df_all['location'].str.split(',')
df_all
# Out:
#                                                    smiles uniprot uni_prot_id
# 0                              CC(=N)NCCSCC[C@H](N)C(=O)O  P35228      P35228  \
# 1                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P20309      P20309
# 3                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P08172      P08172
# 5                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  Q92731      Q92731
# 7                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  P03372      P03372
# ...                                                   ...     ...         ...
# 675170  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9P289      Q9P289
# 675173  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9Y6E0      Q9Y6E0
# 675176  COC1=CC(NC2=NC(NC3=CC=C4OC(C)(C)C(=O)N(COP(O)(...  P0DMS8      P0DMS8
# 675179  CCN(C1CCOCC1)C1=CC(=CC(C(=O)NCC2=C(C)C=C(C)NC2...  Q92800      Q92800
# 675181              FC1=C(C=CC(=C1)C#N)[C@H]1CCC2=CN=CN12  P19099      P19099
#
#                                                  location
# 0                                     [cytoplasm cytosol]
# 1       [cell membrane multi-pass membrane protein, po...
# 3       [cell membrane multi-pass membrane protein, po...
# 5                                               [nucleus]
# 7       [nucleus, cytoplasm, cell membrane peripheral ...
# ...                                                   ...
# 675170                       [cytoplasm, golgi apparatus]
# 675173                     [cytoplasm, nucleus, membrane]
# 675176        [cell membrane multi-pass membrane protein]
# 675179                                          [nucleus]
# 675181  [mitochondrion inner membrane peripheral membr...
#
# [365091 rows x 4 columns]

# %%
df_smiles = pd.DataFrame(df_all['smiles'])

# If you want 'smiles' as the column name in df_smiles
df_smiles.columns = ['smiles']
df_smiles.drop_duplicates(inplace=True)
df_smiles.to_csv('dataset1.csv', index=False)

# %%
old_label=False
file_name = 'new-label-all-final-LV.csv'
if old_label:
    df_label = pd.read_csv(file_name,header=None)
else:
    df_label = pd.read_csv(file_name,header=None)
    df_label = df_label.T.reset_index(drop=True)

df_label = df_label.applymap(lambda s: s.lower() if type(s) == str else s)

label_dict = {}
for label_index, row in enumerate(df_label.itertuples(index=False)):
    for location in row:
        if not isinstance(location, float):
            label_dict[location] = label_index

label_dict = {key.strip(): value for key, value in label_dict.items()}

# %%
df_label.to_csv('label-all-new.csv',index=False, header=False)

# %%
def replace_from_dict(lst, replace_dict):
    return [replace_dict.get(item, item) for item in lst]

# %%
df_all['location'] = df_all['location'].apply(replace_from_dict, args=(label_dict,))
df_all
# Out:
#                                                    smiles uniprot uni_prot_id
# 0                              CC(=N)NCCSCC[C@H](N)C(=O)O  P35228      P35228  \
# 1                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P20309      P20309
# 3                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P08172      P08172
# 5                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  Q92731      Q92731
# 7                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  P03372      P03372
# ...                                                   ...     ...         ...
# 675170  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9P289      Q9P289
# 675173  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9Y6E0      Q9Y6E0
# 675176  COC1=CC(NC2=NC(NC3=CC=C4OC(C)(C)C(=O)N(COP(O)(...  P0DMS8      P0DMS8
# 675179  CCN(C1CCOCC1)C1=CC(=CC(C(=O)NCC2=C(C)C=C(C)NC2...  Q92800      Q92800
# 675181              FC1=C(C=CC(=C1)C#N)[C@H]1CCC2=CN=CN12  P19099      P19099
#
#                                       location
# 0                                          [5]
# 1                             [16, 16, 16, 10]
# 3                                     [16, 16]
# 5                                         [28]
# 7       [28, 5, 16, 28, 5, 16, 16, 28, 11, 30]
# ...                                        ...
# 675170                                 [5, 11]
# 675173                             [5, 28, 30]
# 675176                                    [16]
# 675179                                    [28]
# 675181                                    [21]
#
# [365091 rows x 4 columns]

# %%
df_all['location'] = df_all['location'].apply(lambda lst: [x for x in lst if not isinstance(x, str)])
df_all
# Out:
#                                                    smiles uniprot uni_prot_id
# 0                              CC(=N)NCCSCC[C@H](N)C(=O)O  P35228      P35228  \
# 1                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P20309      P20309
# 3                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P08172      P08172
# 5                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  Q92731      Q92731
# 7                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  P03372      P03372
# ...                                                   ...     ...         ...
# 675170  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9P289      Q9P289
# 675173  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9Y6E0      Q9Y6E0
# 675176  COC1=CC(NC2=NC(NC3=CC=C4OC(C)(C)C(=O)N(COP(O)(...  P0DMS8      P0DMS8
# 675179  CCN(C1CCOCC1)C1=CC(=CC(C(=O)NCC2=C(C)C=C(C)NC2...  Q92800      Q92800
# 675181              FC1=C(C=CC(=C1)C#N)[C@H]1CCC2=CN=CN12  P19099      P19099
#
#                                       location
# 0                                          [5]
# 1                             [16, 16, 16, 10]
# 3                                     [16, 16]
# 5                                         [28]
# 7       [28, 5, 16, 28, 5, 16, 16, 28, 11, 30]
# ...                                        ...
# 675170                                 [5, 11]
# 675173                             [5, 28, 30]
# 675176                                    [16]
# 675179                                    [28]
# 675181                                    [21]
#
# [365091 rows x 4 columns]

# %%
df_all = df_all[df_all['location'].apply(lambda x: len(x) > 0)]
df_all
# Out:
#                                                    smiles uniprot uni_prot_id
# 0                              CC(=N)NCCSCC[C@H](N)C(=O)O  P35228      P35228  \
# 1                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P20309      P20309
# 3                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O  P08172      P08172
# 5                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  Q92731      Q92731
# 7                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O  P03372      P03372
# ...                                                   ...     ...         ...
# 675170  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9P289      Q9P289
# 675173  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...  Q9Y6E0      Q9Y6E0
# 675176  COC1=CC(NC2=NC(NC3=CC=C4OC(C)(C)C(=O)N(COP(O)(...  P0DMS8      P0DMS8
# 675179  CCN(C1CCOCC1)C1=CC(=CC(C(=O)NCC2=C(C)C=C(C)NC2...  Q92800      Q92800
# 675181              FC1=C(C=CC(=C1)C#N)[C@H]1CCC2=CN=CN12  P19099      P19099
#
#                                       location
# 0                                          [5]
# 1                             [16, 16, 16, 10]
# 3                                     [16, 16]
# 5                                         [28]
# 7       [28, 5, 16, 28, 5, 16, 16, 28, 11, 30]
# ...                                        ...
# 675170                                 [5, 11]
# 675173                             [5, 28, 30]
# 675176                                    [16]
# 675179                                    [28]
# 675181                                    [21]
#
# [363905 rows x 4 columns]

# %%
df_all.drop(['uniprot','uni_prot_id'],axis=1,inplace=True)
df_all['location'] = df_all['location'].apply(tuple)
df_all.drop_duplicates(inplace=True)
df_all
# Out:
# /tmp/ipykernel_454038/3082369734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all.drop(['uniprot','uni_prot_id'],axis=1,inplace=True)
# /tmp/ipykernel_454038/3082369734.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['location'] = df_all['location'].apply(tuple)
# /tmp/ipykernel_454038/3082369734.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all.drop_duplicates(inplace=True)
#                                                    smiles
# 0                              CC(=N)NCCSCC[C@H](N)C(=O)O  \
# 1                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O
# 3                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O
# 5                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O
# 7                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O
# ...                                                   ...
# 675167  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...
# 675173  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...
# 675176  COC1=CC(NC2=NC(NC3=CC=C4OC(C)(C)C(=O)N(COP(O)(...
# 675179  CCN(C1CCOCC1)C1=CC(=CC(C(=O)NCC2=C(C)C=C(C)NC2...
# 675181              FC1=C(C=CC(=C1)C#N)[C@H]1CCC2=CN=CN12
#
#                                       location
# 0                                         (5,)
# 1                             (16, 16, 16, 10)
# 3                                     (16, 16)
# 5                                        (28,)
# 7       (28, 5, 16, 28, 5, 16, 16, 28, 11, 30)
# ...                                        ...
# 675167                                 (5, 11)
# 675173                             (5, 28, 30)
# 675176                                   (16,)
# 675179                                   (28,)
# 675181                                   (21,)
#
# [194126 rows x 2 columns]

# %%
df_final = df_all[['smiles','location']]
df_final.to_csv('final_with_smiles_location_LV.csv',index=False)
df_final
# Out:
#                                                    smiles
# 0                              CC(=N)NCCSCC[C@H](N)C(=O)O  \
# 1                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O
# 3                    C[C@@H]1O[C@H](C[N+](C)(C)C)C[C@H]1O
# 5                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O
# 7                          O=C1c2ccccc2C(=O)c2c1ccc(O)c2O
# ...                                                   ...
# 675167  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...
# 675173  CCOC1=CC2=NC=C(C#N)C(NC3=CC=C(OCC4=CC=CC=N4)C(...
# 675176  COC1=CC(NC2=NC(NC3=CC=C4OC(C)(C)C(=O)N(COP(O)(...
# 675179  CCN(C1CCOCC1)C1=CC(=CC(C(=O)NCC2=C(C)C=C(C)NC2...
# 675181              FC1=C(C=CC(=C1)C#N)[C@H]1CCC2=CN=CN12
#
#                                       location
# 0                                         (5,)
# 1                             (16, 16, 16, 10)
# 3                                     (16, 16)
# 5                                        (28,)
# 7       (28, 5, 16, 28, 5, 16, 16, 28, 11, 30)
# ...                                        ...
# 675167                                 (5, 11)
# 675173                             (5, 28, 30)
# 675176                                   (16,)
# 675179                                   (28,)
# 675181                                   (21,)
#
# [194126 rows x 2 columns]

# %%
max_values = df_final['location'].apply(lambda x: max(x) if isinstance(x, tuple) else None)
max_value = max_values.max()
max_value
# Out:
# 33

# %%
min_values = df_final['location'].apply(lambda x: min(x) if isinstance(x, tuple) else None)
min_value = min_values.min()
min_value
# Out:
# 1

# %%
directory = "final_label_to_train_LV"
df_dict = {}
for i in range(max_value+1): 
    df_dict[i] = df_final[df_final['location'].apply(lambda x: i in x)].copy()
    df_dict[i]['label'] = i
    df_dict[i]= df_dict[i][['smiles','label']]
    if not os.path.exists(directory):
        os.makedirs(directory)
    df_dict[i].to_csv(f'{directory}/00_label_{i:02}.csv'.format(i),index=False)

# %%
df_label
# Out:
#                                0
# 0                 actin_filaments  \
# 1                  cell_junctions
# 2                      centrosome
# 3              cytoplasmic_bodies
# 4                    cytoskeleton
# 5                         cytosol
# 6           endoplasmic_reticulum
# 7                        endosome
# 8               endosome_membrane
# 9                        er_lumen
# 10                    er_membrane
# 11                golgi_apparatus
# 12                    golgi_lumen
# 13                 golgi_membrane
# 14                       lysosome
# 15              lysosome_membrane
# 16              membrane_proteins
# 17  microtubule_organizing_center
# 18                        midbody
# 19                   mitochondria
# 20            mitochondria_matrix
# 21         mitochondrial_membrane
# 22                      myofibril
# 23                 nuclear_bodies
# 24               nuclear_membrane
# 25               nuclear_speckles
# 26                      nucleolus
# 27                    nucleoplasm
# 28                        nucleus
# 29                     peroxisome
# 30                plasma_membrane
# 31                       secreted
# 32                        vesicle
# 33               vesicle_membrane
#
#                                                    1
# 0                                 actin cytoplasmic 1  \
# 1                                       cell junction
# 2   cytoplasm cytoskeleton microtubule organizing ...
# 3                                    cytoplasm p-body
# 4                              cytoplasm cytoskeleton
# 5                                   cytolytic granule
# 6                               endoplasmic reticulum
# 7                                            endosome
# 8                                   endosome membrane
# 9                         endoplasmic reticulum lumen
# 10                     endoplasmic reticulum membrane
# 11                                    golgi apparatus
# 12                              golgi apparatus lumen
# 13  golgi apparatus golgi stack membrane multi-pas...
# 14                                           lysosome
# 15                                  lysosome membrane
# 16   apical cell membrane multi-pass membrane protein
# 17  cytoplasm cytoskeleton microtubule organizing ...
# 18                                            midbody
# 19                                      mitochondrion
# 20                  mitochondrion intermembrane space
# 21                       mitochondrion inner membrane
# 22                      cytoplasm myofibril sarcomere
# 23                                 nucleus cajal body
# 24                       nucleus nuclear pore complex
# 25                                    nucleus speckle
# 26                                  nucleus nucleolus
# 27                                         chromosome
# 28                                            nucleus
# 29                                         peroxisome
# 30                               apical cell membrane
# 31                                           secreted
# 32                                cytoplasmic vesicle
# 33         cytoplasmic vesicle autophagosome membrane
#
#                                                    2
# 0                                 actin cytoplasmic 2  \
# 1                     cell junction adherens junction
# 2   cytoplasm cytoskeleton microtubule organizing ...
# 3                                                 NaN
# 4               cytoplasm cytoskeleton cilium axoneme
# 5                          cytolytic granule membrane
# 6   endoplasmic reticulum-golgi intermediate compa...
# 7                        endosome multivesicular body
# 8       endosome membrane multi-pass membrane protein
# 9                        sarcoplasmic reticulum lumen
# 10        endoplasmic reticulum membrane lipid-anchor
# 11                  golgi apparatus cis-golgi network
# 12                                                NaN
# 13  golgi apparatus golgi stack membrane periphera...
# 14                                     lysosome lumen
# 15      lysosome membrane multi-pass membrane protein
# 16  apical cell membrane peripheral membrane prote...
# 17  cytoplasm cytoskeleton microtubule organizing ...
# 18                               midbody midbody ring
# 19                                                NaN
# 20                               mitochondrion matrix
# 21  mitochondrion inner membrane multi-pass membra...
# 22               cytoplasm myofibril sarcomere m line
# 23                                   nucleus pml body
# 24                                   nucleus envelope
# 25                                                NaN
# 26                                                NaN
# 27                              chromosome centromere
# 28                                        nucleus gem
# 29                                  peroxisome matrix
# 30                  apical cell membrane lipid-anchor
# 31                     secreted extracellular exosome
# 32                  cytoplasmic vesicle autophagosome
# 33  cytoplasmic vesicle autophagosome membrane lip...
#
#                                                    3
# 0                         gamma-enteric smooth muscle  \
# 1                             cell junction desmosome
# 2                                                 NaN
# 3                                                 NaN
# 4            cytoplasm cytoskeleton cilium basal body
# 5                                           cytoplasm
# 6                                           microsome
# 7                                      early endosome
# 8       endosome membrane peripheral membrane protein
# 9                                                 NaN
# 10  endoplasmic reticulum membrane lipid-anchor cy...
# 11                golgi apparatus trans-golgi network
# 12                                                NaN
# 13  golgi apparatus golgi stack membrane single-pa...
# 14                                         melanosome
# 15      lysosome membrane peripheral membrane protein
# 16  apical cell membrane peripheral membrane prote...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20        mitochondrion matrix mitochondrion nucleoid
# 21  mitochondrion inner membrane multi-pass membra...
# 22               cytoplasm myofibril sarcomere z line
# 23                                                NaN
# 24                             nucleus inner membrane
# 25                                                NaN
# 26                                                NaN
# 27                  chromosome centromere kinetochore
# 28                        nucleus intermembrane space
# 29    peroxisome membrane multi-pass membrane protein
# 30       apical cell membrane lipid-anchor gpi-anchor
# 31                       secreted extracellular space
# 32            cytoplasmic vesicle autophagosome lumen
# 33  cytoplasmic vesicle autophagosome membrane mul...
#
#                                                    4
# 0                                               actin  \
# 1                        cell junction focal adhesion
# 2                                                 NaN
# 3                                                 NaN
# 4            cytoplasm cytoskeleton flagellum axoneme
# 5                               cytoplasm cell cortex
# 6                         rough endoplasmic reticulum
# 7                                       late endosome
# 8   endosome membrane single-pass type i membrane ...
# 9                                                 NaN
# 10  endoplasmic reticulum-golgi intermediate compa...
# 11                                                NaN
# 12                                                NaN
# 13  golgi apparatus golgi stack membrane single-pa...
# 14                                                NaN
# 15  lysosome membrane peripheral membrane protein ...
# 16  apical cell membrane single-pass type i membra...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  mitochondrion inner membrane peripheral membra...
# 22                                                NaN
# 23                                                NaN
# 24  nucleus inner membrane multi-pass membrane pro...
# 25                                                NaN
# 26                                                NaN
# 27                                chromosome telomere
# 28                                                NaN
# 29  peroxisome membrane peripheral membrane protei...
# 30                                basal cell membrane
# 31  secreted extracellular space extracellular matrix
# 32        cytoplasmic vesicle clathrin-coated vesicle
# 33  cytoplasmic vesicle autophagosome membrane per...
#
#                                                    5
# 0                               alpha skeletal muscle  \
# 1                          cell junction gap junction
# 2                                                 NaN
# 3                                                 NaN
# 4                      cytoplasm cytoskeleton spindle
# 5                                   cytoplasm cytosol
# 6                              sarcoplasmic reticulum
# 7                                  recycling endosome
# 8   endosome membrane single-pass type ii membrane...
# 9                                                 NaN
# 10                                 microsome membrane
# 11                                                NaN
# 12                                                NaN
# 13       golgi apparatus trans-golgi network membrane
# 14                                                NaN
# 15  lysosome membrane peripheral membrane protein ...
# 16  apical cell membrane single-pass type ii membr...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  mitochondrion inner membrane peripheral membra...
# 22                                                NaN
# 23                                                NaN
# 24  nucleus inner membrane peripheral membrane pro...
# 25                                                NaN
# 26                                                NaN
# 27                                nucleus nucleoplasm
# 28                                                NaN
# 29                                                NaN
# 30                          basolateral cell membrane
# 31  secreted extracellular space extracellular mat...
# 32                      cytoplasmic vesicle phagosome
# 33  cytoplasmic vesicle copii-coated vesicle membr...
#
#                                                    6
# 0                                                 NaN  \
# 1                         cell junction hemidesmosome
# 2                                                 NaN
# 3                                                 NaN
# 4                 cytoplasm cytoskeleton spindle pole
# 5                        cytoplasm perinuclear region
# 6                                                 NaN
# 7                                                 NaN
# 8                             early endosome membrane
# 9                                                 NaN
# 10                    microsome membrane lipid-anchor
# 11                                                NaN
# 12                                                NaN
# 13  golgi apparatus trans-golgi network membrane l...
# 14                                                NaN
# 15  lysosome membrane single-pass type i membrane ...
# 16  apicolateral cell membrane multi-pass membrane...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  mitochondrion inner membrane peripheral membra...
# 22                                                NaN
# 23                                                NaN
# 24                                     nucleus lamina
# 25                                                NaN
# 26                                                NaN
# 27                                     nucleus matrix
# 28                                                NaN
# 29                                                NaN
# 30  basolateral cell membrane lipid-anchor gpi-lik...
# 31          secreted extracellular space surface film
# 32              cytoplasmic vesicle secretory vesicle
# 33  cytoplasmic vesicle clathrin-coated vesicle me...
#
#                                                    7
# 0                                                 NaN  \
# 1            cell junction paranodal septate junction
# 2                                                 NaN
# 3                                                 NaN
# 4                 cytoplasm cytoskeleton stress fiber
# 5                            cytoplasm stress granule
# 6                                                 NaN
# 7                                                 NaN
# 8   early endosome membrane multi-pass membrane pr...
# 9                                                 NaN
# 10  endoplasmic reticulum membrane multi-pass memb...
# 11                                                NaN
# 12                                                NaN
# 13  golgi apparatus trans-golgi network membrane m...
# 14                                                NaN
# 15  lysosome membrane single-pass type ii membrane...
# 16    basal cell membrane multi-pass membrane protein
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  mitochondrion inner membrane single-pass membr...
# 22                                                NaN
# 23                                                NaN
# 24                                   nucleus membrane
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                      cell membrane
# 31                                                NaN
# 32     cytoplasmic vesicle secretory vesicle acrosome
# 33  cytoplasmic vesicle clathrin-coated vesicle me...
#
#                                                    8
# 0                                                 NaN  \
# 1                        cell junction tight junction
# 2                                                 NaN
# 3                                                 NaN
# 4                            dynein axonemal particle
# 5                                 cytoplasmic granule
# 6                                                 NaN
# 7                                                 NaN
# 8   early endosome membrane peripheral membrane pr...
# 9                                                 NaN
# 10  endoplasmic reticulum membrane peripheral memb...
# 11                                                NaN
# 12                                                NaN
# 13  golgi apparatus trans-golgi network membrane p...
# 14                                                NaN
# 15    melanosome membrane multi-pass membrane protein
# 16  basolateral cell membrane multi-pass membrane ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  mitochondrion inner membrane single-pass membr...
# 22                                                NaN
# 23                                                NaN
# 24                      nucleus membrane lipid-anchor
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                         cell membrane lipid-anchor
# 31                                                NaN
# 32  cytoplasmic vesicle secretory vesicle chromaff...
# 33  cytoplasmic vesicle clathrin-coated vesicle me...
#
#                                                    9   ...
# 0                                                 NaN  ...  \
# 1                                                 NaN  ...
# 2                                                 NaN  ...
# 3                                                 NaN  ...
# 4                                                 NaN  ...
# 5                                        inflammasome  ...
# 6                                                 NaN  ...
# 7                                                 NaN  ...
# 8   early endosome membrane peripheral membrane pr...  ...
# 9                                                 NaN  ...
# 10  endoplasmic reticulum membrane peripheral memb...  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13  golgi apparatus trans-golgi network membrane s...  ...
# 14                                                NaN  ...
# 15  melanosome membrane peripheral membrane protei...  ...
# 16  basolateral cell membrane peripheral membrane ...  ...
# 17                                                NaN  ...
# 18                                                NaN  ...
# 19                                                NaN  ...
# 20                                                NaN  ...
# 21                             mitochondrion membrane  ...
# 22                                                NaN  ...
# 23                                                NaN  ...
# 24       nucleus membrane multi-pass membrane protein  ...
# 25                                                NaN  ...
# 26                                                NaN  ...
# 27                                                NaN  ...
# 28                                                NaN  ...
# 29                                                NaN  ...
# 30        cell membrane lipid-anchor cytoplasmic side  ...
# 31                                                NaN  ...
# 32  cytoplasmic vesicle secretory vesicle chromaff...  ...
# 33             cytoplasmic vesicle phagosome membrane  ...
#
#                                                    33
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16     membrane single-pass type iii membrane protein
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  zymogen granule membrane peripheral membrane p...
#
#                                                    34
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  membrane raft peripheral membrane protein extr...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  extracellular vesicle membrane lipid-anchor gp...
#
#                                                    35
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  membrane raft single-pass type i membrane protein
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                                                    36
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  postsynaptic cell membrane multi-pass membrane...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                                                    37
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  postsynaptic cell membrane peripheral membrane...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                                                    38
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  postsynaptic cell membrane single-pass type i ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                                                    39
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  postsynaptic density membrane multi-pass membr...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                                                    40
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  presynaptic cell membrane multi-pass membrane ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                                                    41
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  synaptic cell membrane multi-pass membrane pro...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                                                   42
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16  target cell membrane multi-pass membrane protein
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
#
# [34 rows x 43 columns]

# %%
new_df_label = pd.DataFrame()
new_df_label['sublocation'] = df_label[[0]].copy()
new_df_label['label'] = df_label.index
new_df_label
# Out:
#                       sublocation  label
# 0                 actin_filaments      0
# 1                  cell_junctions      1
# 2                      centrosome      2
# 3              cytoplasmic_bodies      3
# 4                    cytoskeleton      4
# 5                         cytosol      5
# 6           endoplasmic_reticulum      6
# 7                        endosome      7
# 8               endosome_membrane      8
# 9                        er_lumen      9
# 10                    er_membrane     10
# 11                golgi_apparatus     11
# 12                    golgi_lumen     12
# 13                 golgi_membrane     13
# 14                       lysosome     14
# 15              lysosome_membrane     15
# 16              membrane_proteins     16
# 17  microtubule_organizing_center     17
# 18                        midbody     18
# 19                   mitochondria     19
# 20            mitochondria_matrix     20
# 21         mitochondrial_membrane     21
# 22                      myofibril     22
# 23                 nuclear_bodies     23
# 24               nuclear_membrane     24
# 25               nuclear_speckles     25
# 26                      nucleolus     26
# 27                    nucleoplasm     27
# 28                        nucleus     28
# 29                     peroxisome     29
# 30                plasma_membrane     30
# 31                       secreted     31
# 32                        vesicle     32
# 33               vesicle_membrane     33

# %%
new_df_label.to_csv('label_subloc_LV.csv', index=False)

# %%
df_label[[0]]
# Out:
#                                 0
# 0                 actin_filaments
# 1                  cell_junctions
# 2                      centrosome
# 3              cytoplasmic_bodies
# 4                    cytoskeleton
# 5                         cytosol
# 6           endoplasmic_reticulum
# 7                        endosome
# 8               endosome_membrane
# 9                        er_lumen
# 10                    er_membrane
# 11                golgi_apparatus
# 12                    golgi_lumen
# 13                 golgi_membrane
# 14                       lysosome
# 15              lysosome_membrane
# 16              membrane_proteins
# 17  microtubule_organizing_center
# 18                        midbody
# 19                   mitochondria
# 20            mitochondria_matrix
# 21         mitochondrial_membrane
# 22                      myofibril
# 23                 nuclear_bodies
# 24               nuclear_membrane
# 25               nuclear_speckles
# 26                      nucleolus
# 27                    nucleoplasm
# 28                        nucleus
# 29                     peroxisome
# 30                plasma_membrane
# 31                       secreted
# 32                        vesicle
# 33               vesicle_membrane
